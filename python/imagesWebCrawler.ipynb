# %% [markdown]
# # Google Images Web Crawler
# This program takes a string and divvies it up into words, then searches the web for each word, extracting as many URLs as it can find. The URLs are used to download images. The images are then scaled to 640x640 px and labeled with the search term used to find it.
#
# Please use your own Project Key (console.cloud.google.com) and Search Engine (cse.google.com). They're both free :p

# %% [markdown]
# #### First, import dependent libraries.

# %%
import os
import sys
import time
import urllib3 as urllib3
import urllib.request
import simplejson
from io import StringIO
import pprint
from googleapiclient.discovery import build
from PIL import Image, ImageFont, ImageDraw
from random import randint

# %% [markdown]
# ### Create a search string. Each word is searched independently.

# %%
# insert favorite wilco line
searchString = '''im the boy with the poetry power im the boy who smells like flowers'''

searchTerms = searchString.split()
print(str(len(searchTerms)))
# Out:
# 14

# %% [markdown]
# ### Use a custom search engine generated in cse.google.com on the project generated in console.cloud.google.com
# Search the web for each word and append the dict of the result to a list of dicts (results).

# %%
projectKey = "AIzaSyC2j8I9Qsoiop80HT6nsm4pxYF5BG6uORM"
searchEngineID = '008351460169727747582:0ryy6yqws-o'

# instantiate the service
service = build("customsearch", "v1",
        developerKey=projectKey)

# avoid gifs
gifExclude = '-filetype:gif'

# may need to change this if you're getting errors
# the errors are caused by google not finding enough
# results to start at the given point
maxStart = 10

results = []
for term in searchTerms:
    # random starting point for each image between 0-19
    startPoint = randint(0,maxStart)
    
    results.append(service.cse().list(
        start = startPoint,
        # max # of images to return
        num = 10,
        q = term,
        cx = searchEngineID
        #imgtype = 'face'
        ).execute())

print(str(len(results)) + '\n')
pprint.pprint(results)
# Out:
# 14
#
# [{'context': {'title': 'Image Crawler'},
#   'items': [{'cacheId': 'nnq_ZsLqlFEJ',
#              'displayLink': 'play.google.com',
#              'formattedUrl': 'https://play.google.com/store/apps/details?id=de.shapeservices...',
#              'htmlFormattedUrl': 'https://play.google.com/store/apps/details?id=de.shapeservices...',
#              'htmlSnippet': 'IM+ supports simultaneously major <b>IM</b> '
#                             'services, including Google Talk, Twitter <br>\n'
#                             'DMs, Yahoo!, AIM/iChat, ICQ, Jabber (and Slack '
#                             'through Jabber), and many&nbsp;...',
#              'htmlTitle': 'IM+ - Android Apps on Google Play',
#              'kind': 'customsearch#result',
#              'link': 'https://play.google.com/store/apps/details?id=de.shapeservices.impluslite',
#              'pagemap': {'aggregaterating': [{'ratingcount': '90514',
#                                               'ratingvalue': '4.170305252075195'}],
#                          'cse_image': [{'src': 'https://lh4.ggpht.com/7WFBFNz6ym0PrH_yHG-VMYjudkRAAJuo4G36LdbDhOoXMIKEXZut57PSOL5iLlweKAUN=w300'}],
#                          'cse_thumbnail': [{'height': '225',
#                                             'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRmhjirKqB-HN7gHs4YVvviEJMHjvcTIWfjC1j8rcn6_1uBmtTvgBRmScyf',
#                                             'width': '225'}],
#                          'metatags': [{'og:title': 'IM+ - Android Apps on '
#                                                    'Google Play',
#                                        'og:type': 'website',
#                                        'og:url': 'https://play.google.com/store/apps/details?id=de.shapeservices.impluslite'}],
#                          'mobileapplication': [{'contentrating': 'Everyone',
#                                                 'datepublished': 'October 24, '
#                                                                  '2016',
#                                                 'description': 'IM+ supports '
#                                                                'simultaneously '
#                                                                'major IM '
#                                                                'services, '
#                                                                'including '
#                                                                'Google Talk, '
#                                                                'Twitter DMs, '
#                                                                'Yahoo!, '
#                                                                'AIM/iChat, '
#                                                                'ICQ, Jabber '
#                                                                '(and Slack '
#                                                                'through '
#                                                                'Jabber), and '
#                                                                'many '
#                                                                'others.Below '
#                                                                'is the list of '
#                                                                'other IM+...',
#                                                 'filesize': 'Varies with '
#                                                             'device',
#                                                 'image': 'https://lh4.ggpht.com/7WFBFNz6ym0PrH_yHG-VMYjudkRAAJuo4G36LdbDhOoXMIKEXZut57PSOL5iLlweKAUN=w300',
#                                                 'name': 'IM+',
#                                                 'numdownloads': '5,000,000 - '
#                                                                 '10,000,000',
#                                                 'operatingsystems': 'Varies '
#                                                                     'with '
#                                                                     'device',
#                                                 'screenshot': 'https://lh5.ggpht.com/9DovkLv2ZpsBzTR8Lh3cry1PINs7NBBVD96nYHKlm1NVkRL9NHx0Xgu-pFQHqOU8aRf0=h310',
#                                                 'softwareversion': 'Varies '
#                                                                    'with '
#                                                                    'device',
#                                                 'url': 'https://play.google.com/store/apps/details?id=de.shapeservices.impluslite'}],
#                          'offer': [{'price': '0',
#                                     'url': 'https://play.google.com/store/apps/details?id=de.shapeservices.impluslite&rdid=de.shapeservices.impluslite&feature=md&rdot=1'}],
#                          'organization': [{'genre': 'Communication',
#                                            'name': 'SHAPE',
#                                            'url': '/store/apps/developer?id=SHAPE'},
#                                           {'name': 'Android'}]},
#              'snippet': 'IM+ supports simultaneously major IM services, '
#                         'including Google Talk, Twitter \n'
#                         'DMs, Yahoo!, AIM/iChat, ICQ, Jabber (and Slack '
#                         'through Jabber), and many\xa0...',
#              'title': 'IM+ - Android Apps on Google Play'},
#             {'cacheId': 'n79obJgQXqIJ',
#              'displayLink': 'play.google.com',
#              'formattedUrl': 'https://play.google.com/store/apps/details?id=com.skype.raider',
#              'htmlFormattedUrl': 'https://play.google.com/store/apps/details?id=com.skype.raider',
#              'htmlSnippet': 'Skype keeps the world talking. Say “hello” with '
#                             'an instant message, voice or <br>\n'
#                             'video call—all for free, no matter what device '
#                             'they use Skype on. • Talk face to <br>\n'
#                             'face&nbsp;...',
#              'htmlTitle': 'Skype - free <b>IM</b> &amp; video calls - Android '
#                           'Apps on Google Play',
#              'kind': 'customsearch#result',
#              'link': 'https://play.google.com/store/apps/details?id=com.skype.raider',
#              'pagemap': {'aggregaterating': [{'ratingcount': '9776958',
#                                               'ratingvalue': '4.138181209564209'}],
#                          'cse_image': [{'src': 'https://i.ytimg.com/vi/5DKGe_oEajs/hqdefault.jpg'}],
#                          'cse_thumbnail': [{'height': '194',
#                                             'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR3pehJ0OA1AaroihTAMMsw4znmWB2HlfWTwKWqvt3CUC0j2glNuivLIxYh',
#                                             'width': '259'}],
#                          'metatags': [{'og:title': 'Skype - free IM & video '
#                                                    'calls - Android Apps on '
#                                                    'Google Play',
#                                        'og:type': 'website',
#                                        'og:url': 'https://play.google.com/store/apps/details?id=com.skype.raider'}],
#                          'mobileapplication': [{'contentrating': 'Everyone',
#                                                 'datepublished': 'April 11, '
#                                                                  '2017',
#                                                 'description': 'Skype keeps '
#                                                                'the world '
#                                                                'talking. Say '
#                                                                '“hello” with '
#                                                                'an instant '
#                                                                'message, voice '
#                                                                'or video '
#                                                                'call—all for '
#                                                                'free, no '
#                                                                'matter what '
#                                                                'device they '
#                                                                'use Skype on. '
#                                                                '• Talk face to '
#                                                                'face with a '
#                                                                'video call....',
#                                                 'filesize': 'Varies with '
#                                                             'device',
#                                                 'image': 'https://lh5.ggpht.com/1CxNUEdzrREikWZoaHIU5J63x2gOxTb7R-ZIbJd51uPBFt0jUj8AX2bMOhKiIBcuAqtH=w300',
#                                                 'name': 'Skype - free IM & '
#                                                         'video calls',
#                                                 'numdownloads': '500,000,000 - '
#                                                                 '1,000,000,000',
#                                                 'operatingsystems': 'Varies '
#                                                                     'with '
#                                                                     'device',
#                                                 'screenshot': 'https://lh3.googleusercontent.com/ZuuNVuHng6xIo6jpTcp6bAYj8lSOeAREhNo5C3UvNzrTXf5sej2m-px0992tWHiLy3t5=h310',
#                                                 'softwareversion': 'Varies '
#                                                                    'with '
#                                                                    'device',
#                                                 'topdeveloperbadgeurl': 'https://www.gstatic.com/android/market_images/badges/topdev_ann.png',
#                                                 'url': 'https://play.google.com/store/apps/details?id=com.skype.raider'}],
#                          'offer': [{'price': '0',
#                                     'url': 'https://play.google.com/store/apps/details?id=com.skype.raider&rdid=com.skype.raider&feature=md&rdot=1'}],
#                          'organization': [{'genre': 'Communication',
#                                            'name': 'Skype',
#                                            'url': '/store/apps/developer?id=Skype'},
#                                           {'name': 'Android'}]},
#              'snippet': 'Skype keeps the world talking. Say “hello” with an '
#                         'instant message, voice or \n'
#                         'video call—all for free, no matter what device they '
#                         'use Skype on. • Talk face to \n'
#                         'face\xa0...',
#              'title': 'Skype - free IM & video calls - Android Apps on Google '
#                       'Play'},
#             {'cacheId': 'DR5elG7cXCcJ',
#              'displayLink': 'play.google.com',
#              'formattedUrl': 'https://play.google.com/store/apps/details?id=com.imo.android...',
#              'htmlFormattedUrl': 'https://play.google.com/store/apps/details?id=com.imo.android...',
#              'htmlSnippet': 'Message and video call your friends and family '
#                             'for free, no matter what device <br>\n'
#                             'they are on! - Make high-quality video and voice '
#                             'calls on Android and iPhone',
#              'htmlTitle': 'imo free video calls and chat - Android Apps on '
#                           'Google Play',
#              'kind': 'customsearch#result',
#              'link': 'https://play.google.com/store/apps/details?id=com.imo.android.imoim',
#              'pagemap': {'aggregaterating': [{'ratingcount': '3604467',
#                                               'ratingvalue': '4.26043701171875'}],
#                          'cse_image': [{'src': 'https://lh3.googleusercontent.com/tm_N1osJGfifuRlMfEip4kZFD5QCtd42CYYEhUsxABzIoEn6Nb9UXjRVmjoeKvMFUCzF=w300'}],
#                          'cse_thumbnail': [{'height': '225',
#                                             'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQRJktNmhntbhJUs5kbPiQ5_zlJLx6p-wf__HaW2Mzqry6Zi1Vf6jjjW4rk',
#                                             'width': '225'}],
#                          'metatags': [{'og:title': 'imo free video calls and '
#                                                    'chat - Android Apps on '
#                                                    'Google Play',
#                                        'og:type': 'website',
#                                        'og:url': 'https://play.google.com/store/apps/details?id=com.imo.android.imoim'}],
#                          'mobileapplication': [{'contentrating': 'Everyone',
#                                                 'datepublished': 'April 17, '
#                                                                  '2017',
#                                                 'description': 'Message and '
#                                                                'video call '
#                                                                'your friends '
#                                                                'and family for '
#                                                                'free, no '
#                                                                'matter what '
#                                                                'device they '
#                                                                'are on! - Make '
#                                                                'high-quality '
#                                                                'video and '
#                                                                'voice calls on '
#                                                                'Android and '
#                                                                'iPhone - Send '
#                                                                'unlimited '
#                                                                'messages and '
#                                                                'make...',
#                                                 'image': 'https://lh3.googleusercontent.com/tm_N1osJGfifuRlMfEip4kZFD5QCtd42CYYEhUsxABzIoEn6Nb9UXjRVmjoeKvMFUCzF=w300',
#                                                 'name': 'imo free video calls '
#                                                         'and chat',
#                                                 'numdownloads': '100,000,000 - '
#                                                                 '500,000,000',
#                                                 'operatingsystems': '4.0 and '
#                                                                     'up',
#                                                 'screenshot': 'https://lh6.ggpht.com/5Tms-0_js1mj5kIunsEmrDG1FTVnvXuXcr2mHCJm8XeVkY73Knnw3jGAHqnHdJMDj28=h310',
#                                                 'softwareversion': '9.8.000000006011',
#                                                 'topdeveloperbadgeurl': 'https://www.gstatic.com/android/market_images/badges/topdev_ann.png',
#                                                 'url': 'https://play.google.com/store/apps/details?id=com.imo.android.imoim'}],
#                          'offer': [{'price': '0',
#                                     'url': 'https://play.google.com/store/apps/details?id=com.imo.android.imoim&rdid=com.imo.android.imoim&feature=md&rdot=1'}],
#                          'organization': [{'genre': 'Communication',
#                                            'name': 'imo.im',
#                                            'url': '/store/apps/developer?id=imo.im'},
#                                           {'name': 'Android'}]},
#              'snippet': 'Message and video call your friends and family for '
#                         'free, no matter what device \n'
#                         'they are on! - Make high-quality video and voice '
#                         'calls on Android and iPhone',
#              'title': 'imo free video calls and chat - Android Apps on Google '
#                       'Play'},
#             {'cacheId': 'sy-D77RyEuoJ',
#              'displayLink': 'chrome.google.com',
#              'formattedUrl': 'https://chrome.google.com/webstore/category/app/75-chat-and-im',
#              'htmlFormattedUrl': 'https://chrome.google.com/webstore/category/app/75-chat-and-<b>im</b>',
#              'htmlSnippet': 'Discover great apps, games, extensions and themes '
#                             'for Google Chrome.',
#              'htmlTitle': 'Chrome Web Store - Chat &amp; <b>IM</b>',
#              'kind': 'customsearch#result',
#              'link': 'https://chrome.google.com/webstore/category/app/75-chat-and-im',
#              'pagemap': {'cse_image': [{'src': 'https://lh3.googleusercontent.com/oX_BXjux5mD3rGGed7S7paT-DQjlScg2Cb1pCzm7gH0XrqmZsBtcKNyprMpA59PkiLnxDccWwA=s220-h140-e365'}],
#                          'cse_thumbnail': [{'height': '112',
#                                             'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSO1P-_3I7bGsOtesIb6j73w3AM3cwbudxR0g_LkwurdPUCsXDoQRqIwW8',
#                                             'width': '176'}],
#                          'metatags': [{'og:description': 'Discover great apps, '
#                                                          'games, extensions '
#                                                          'and themes for '
#                                                          'Google Chrome.',
#                                        'og:image': 'https://ssl.gstatic.com/chrome/webstore/images/chrome_web_store-128.png',
#                                        'og:title': 'Chrome Web Store',
#                                        'og:type': 'website',
#                                        'og:url': 'https://chrome.google.com/webstore',
#                                        'referrer': 'origin',
#                                        'viewport': 'width=device-width, '
#                                                    'initial-scale=1.0, '
#                                                    'maximum-scale=1.0'}]},
#              'snippet': 'Discover great apps, games, extensions and themes for '
#                         'Google Chrome.',
#              'title': 'Chrome Web Store - Chat & IM'},
#             {'cacheId': 'VkB7GmhGk_IJ',
#              'displayLink': 'fonts.google.com',
#              'formattedUrl': 'https://fonts.google.com/specimen/IM+Fell+English+SC',
#              'htmlFormattedUrl': 'https://fonts.google.com/specimen/<b>IM</b>+Fell+English+SC',
#              'htmlSnippet': 'Making the web more beautiful, fast, and open '
#                             'through great typography.',
#              'htmlTitle': '<b>IM</b> Fell English SC - Google Fonts',
#              'kind': 'customsearch#result',
#              'link': 'https://fonts.google.com/specimen/IM+Fell+English+SC',
#              'pagemap': {'cse_image': [{'src': 'https://www.gstatic.com/images/icons/material/apps/fonts/1x/opengraph_color_1200dp.png'}],
#                          'cse_thumbnail': [{'height': '163',
#                                             'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRsBVfSX_idJK2SLeS9coQLP87QlhjSzfqIcksy4NfLKoXgZXZXN0MFrKs',
#                                             'width': '310'}],
#                          'metatags': [{'apple-mobile-web-app-capable': 'yes',
#                                        'apple-mobile-web-app-status-bar-style': 'black-translucent',
#                                        'og:description': 'Making the web more '
#                                                          'beautiful, fast, and '
#                                                          'open through great '
#                                                          'typography',
#                                        'og:image': 'https://www.gstatic.com/images/icons/material/apps/fonts/1x/opengraph_color_1200dp.png',
#                                        'og:site_name': 'Google Fonts',
#                                        'og:title': 'Google Fonts',
#                                        'og:url': 'https://fonts.google.com/',
#                                        'viewport': 'width=device-width, '
#                                                    'minimum-scale=1.0, '
#                                                    'maximum-scale=1.0, '
#                                                    'user-scalable=no'}],
#                          'organization': [{'name': 'Google Fonts'}]},
#              'snippet': 'Making the web more beautiful, fast, and open through '
#                         'great typography.',
#              'title': 'IM Fell English SC - Google Fonts'},
#             {'cacheId': 'Pc010xyKV90J',
#              'displayLink': 'feedproxy.google.com',
#              'formattedUrl': 'feedproxy.google.com/~r/soompi/~3/Xw_3rrbipCc/',
#              'htmlFormattedUrl': 'feedproxy.google.com/~r/soompi/~3/Xw_3rrbipCc/',
#              'htmlSnippet': '2 days ago <b>...</b> MBC&#39;s new drama, '
#                             '&quot;The King Loves&quot; (working title), '
#                             'revealed a still of actors <b>Im</b> <br>\n'
#                             'Siwan, Hong Jong Hyun, and Girls&#39; '
#                             'Generation&#39;s YoonA on April&nbsp;...',
#              'htmlTitle': '<b>Im</b> Siwan, Hong Jong Hyun, And YoonA Are A '
#                           'Lovely Trio In ...',
#              'kind': 'customsearch#result',
#              'link': 'http://feedproxy.google.com/~r/soompi/~3/Xw_3rrbipCc/',
#              'pagemap': {'cse_image': [{'src': 'https://0.soompi.io/wp-content/uploads/2017/04/21093159/YoonA-Hong-Jong-Hyun-Im-Siwan.jpg'}],
#                          'cse_thumbnail': [{'height': '183',
#                                             'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcR3R3NM7K2KWg_LuCkqWD1o8WsmF6LCuhLyOs__qlYxzSnVEIW9PuYM0RQJ',
#                                             'width': '275'}],
#                          'metatags': [{'apple-itunes-app': 'app-id=1065452158',
#                                        'article:modified_time': '2017-04-21T09:58:53-07:00',
#                                        'article:published_time': '2017-04-21T09:58:35-07:00',
#                                        'article:publisher': 'https://www.facebook.com/soompi/',
#                                        'article:section': 'Drama Preview',
#                                        'article:tag': "Girls' Generation",
#                                        'fb:app_id': '163414424111',
#                                        'framework': 'Alkivia Framework 0.8',
#                                        'google-play-app': 'app-id=com.ml.soompi',
#                                        'og:description': 'MBC’s new drama, '
#                                                          '“The King Loves” '
#                                                          '(working title), '
#                                                          'revealed a still of '
#                                                          'actors Im Siwan, '
#                                                          'Hong Jong Hyun, and '
#                                                          'Girls’ Generation’s '
#                                                          'YoonA on April 21. '
#                                                          'The drama\xa0is a '
#                                                          'mellow historical '
#                                                          'fiction that tells '
#                                                          'a\xa0story of love '
#                                                          'and desire between '
#                                                          'the three leads. It '
#                                                          'is based in the '
#                                                          'Goryeo era, and is '
#                                                          '100 percent '
#                                                          'pre-produced. The '
#                                                          'still is from a '
#                                                          'shoot from April 16 '
#                                                          'in Ganghwa County '
#                                                          'with Wang Won (Im '
#                                                          'Siwan), Eun San, '
#                                                          '(YoonA), and Wang '
#                                                          'Rin (Hong Jong '
#                                                          'Hyun). The three of '
#                                                          'them look like '
#                                                          'they’re enjoying '
#                                                          'each other’s '
#                                                          'company\xa0between '
#                                                          'the beautiful spring '
#                                                          'flowers. The drama '
#                                                          'is slated to air '
#                                                          'some time this year. '
#                                                          'Source (1) '
#                                                          '(function($){ '
#                                                          '$(function(){ '
#                                                          "$('.content-body').find('a').each(function(i, "
#                                                          'o){ var target = '
#                                                          '$(o); var attr = '
#                                                          "target.attr('target'); "
#                                                          '//var isInternal = '
#                                                          "(target.attr('href').match(/^https?:\\/\\/(?:www\\.)?soompi\\.com/)) "
#                                                          '? RegExp.$1 : false; '
#                                                          'if(typeof attr === '
#                                                          'typeof undefined){ '
#                                                          "target.attr('target', "
#                                                          "'_blank'); } }); }); "
#                                                          '})(jQuery);...',
#                                        'og:image': 'https://0.soompi.io/wp-content/uploads/2017/04/21093159/YoonA-Hong-Jong-Hyun-Im-Siwan.jpg',
#                                        'og:image:height': '347',
#                                        'og:image:width': '520',
#                                        'og:locale': 'en_US',
#                                        'og:site_name': 'Soompi',
#                                        'og:title': 'Im Siwan, Hong Jong Hyun, '
#                                                    'And YoonA Are A Lovely '
#                                                    'Trio In Upcoming MBC Drama',
#                                        'og:type': 'article',
#                                        'og:updated_time': '2017-04-21T09:58:53-07:00',
#                                        'og:url': 'https://www.soompi.com/2017/04/21/im-siwan-hong-jong-hyun-yoona-lovely-trio-stills-upcoming-mbc-drama/',
#                                        'title': 'Im Siwan, Hong Jong Hyun, And '
#                                                 'YoonA Are A Lovely Trio In '
#                                                 'Upcoming MBC Drama | Soompi',
#                                        'twitter:card': 'summary_large_image',
#                                        'twitter:creator': '@soompi',
#                                        'twitter:description': 'MBC’s new '
#                                                               'drama, “The '
#                                                               'King Loves” '
#                                                               '(working '
#                                                               'title), '
#                                                               'revealed a '
#                                                               'still of actors '
#                                                               'Im Siwan, Hong '
#                                                               'Jong Hyun, and '
#                                                               'Girls’ '
#                                                               'Generation’s '
#                                                               'YoonA on April '
#                                                               '21. The '
#                                                               'drama\xa0is a '
#                                                               'mellow '
#                                                               'historical '
#                                                               'fiction that '
#                                                               'tells a\xa0'
#                                                               'story of love '
#                                                               'and desire '
#                                                               'between the '
#                                                               'three leads. It '
#                                                               'is based in the '
#                                                               'Goryeo era, and '
#                                                               'is 100 percent '
#                                                               'pre-produced. '
#                                                               'The still is '
#                                                               'from a shoot '
#                                                               'from April 16 '
#                                                               'in Ganghwa '
#                                                               'County with '
#                                                               'Wang Won (Im '
#                                                               'Siwan), Eun '
#                                                               'San, (YoonA), '
#                                                               'and Wang Rin '
#                                                               '(Hong Jong '
#                                                               'Hyun). The '
#                                                               'three of them '
#                                                               'look like '
#                                                               'they’re '
#                                                               'enjoying each '
#                                                               'other’s '
#                                                               'company\xa0'
#                                                               'between the '
#                                                               'beautiful '
#                                                               'spring flowers. '
#                                                               'The drama is '
#                                                               'slated to air '
#                                                               'some time this '
#                                                               'year. Source '
#                                                               '(1) '
#                                                               '(function($){ '
#                                                               '$(function(){ '
#                                                               "$('.content-body').find('a').each(function(i, "
#                                                               'o){ var target '
#                                                               '= $(o); var '
#                                                               'attr = '
#                                                               "target.attr('target'); "
#                                                               '//var '
#                                                               'isInternal = '
#                                                               "(target.attr('href').match(/^https?:\\/\\/(?:www\\.)?soompi\\.com/)) "
#                                                               '? RegExp.$1 : '
#                                                               'false; '
#                                                               'if(typeof attr '
#                                                               '=== typeof '
#                                                               'undefined){ '
#                                                               "target.attr('target', "
#                                                               "'_blank'); } "
#                                                               '}); }); '
#                                                               '})(jQuery);...',
#                                        'twitter:image': 'https://0.soompi.io/wp-content/uploads/2017/04/21093159/YoonA-Hong-Jong-Hyun-Im-Siwan.jpg',
#                                        'twitter:image:src': 'https://0.soompi.io/wp-content/uploads/2017/04/21093159/YoonA-Hong-Jong-Hyun-Im-Siwan.jpg',
#                                        'twitter:site': '@soompi',
#                                        'twitter:title': 'Im Siwan, Hong Jong '
#                                                         'Hyun, And YoonA Are A '
#                                                         'Lovely Trio In '
#                                                         'Upcoming MBC Drama',
#                                        'viewport': 'width=device-width, '
#                                                    'initial-scale=1.0, '
#                                                    'minimum-scale=1.0, '
#                                                    'maximum-scale=1.0, '
#                                                    'user-scalable=no'}]},
#              'snippet': '2 days ago ... MBC\'s new drama, "The King Loves" '
#                         '(working title), revealed a still of actors Im \n'
#                         "Siwan, Hong Jong Hyun, and Girls' Generation's YoonA "
#                         'on April\xa0...',
#              'title': 'Im Siwan, Hong Jong Hyun, And YoonA Are A Lovely Trio '
#                       'In ...'},
#             {'cacheId': 'eTfcc1zhRVEJ',
#              'displayLink': 'www.google.com',
#              'formattedUrl': 'www.google.com/finance?cid=659500',
#              'htmlFormattedUrl': 'www.google.com/finance?cid=659500',
#              'htmlSnippet': 'Get detailed financial information on <b>Ingram '
#                             'Micro</b> Inc. (NYSE:<b>IM</b>) including '
#                             'real-<br>\n'
#                             'time stock quotes, historical charts &amp; '
#                             'financial news, all for free!',
#              'htmlTitle': '<b>Ingram Micro</b> Inc.: NYSE:<b>IM</b> quotes '
#                           '&amp; news - Google Finance',
#              'kind': 'customsearch#result',
#              'link': 'http://www.google.com/finance?cid=659500',
#              'pagemap': {'financialquote': [{'afterhoursprice': '38.89',
#                                              'afterhourspricechange': '0.00',
#                                              'afterhourspricechangepercent': '0.00',
#                                              'afterhoursquotetime': '2016-12-05T21:56:52Z',
#                                              'datasource': 'NYSE real-time '
#                                                            'data',
#                                              'datasourcedisclaimerurl': '//www.google.com/help/stock_disclaimer.html#realtime',
#                                              'exchange': 'NYSE',
#                                              'exchangetimezone': 'America/New_York',
#                                              'imageurl': 'https://www.google.com/finance/chart?cht=g&q=NYSE:IM&tkr=1&p=1d&enddatetime=2016-12-05T16:00:12Z',
#                                              'isafterhours': 'true',
#                                              'name': 'Ingram Micro Inc.',
#                                              'price': '38.89',
#                                              'pricecurrency': 'USD',
#                                              'quotetime': '2016-12-05T16:00:12Z',
#                                              'tickersymbol': 'IM',
#                                              'url': 'https://www.google.com/finance?cid=659500'}]},
#              'snippet': 'Get detailed financial information on Ingram Micro '
#                         'Inc. (NYSE:IM) including real-\n'
#                         'time stock quotes, historical charts & financial '
#                         'news, all for free!',
#              'title': 'Ingram Micro Inc.: NYSE:IM quotes & news - Google '
#                       'Finance'},
#             {'cacheId': 'J02OG9VOJzYJ',
#              'displayLink': 'play.google.com',
#              'formattedUrl': 'https://play.google.com/store/apps/developer?id=imo.im',
#              'htmlFormattedUrl': 'https://play.google.com/store/apps/developer?id=imo.<b>im</b>',
#              'htmlSnippet': 'With over a million apps and games, Google Play '
#                             'has something for everyone. <br>\n'
#                             'Browse and install your favorite Android apps and '
#                             'games on your Android phone<br>\n'
#                             ',&nbsp;...',
#              'htmlTitle': 'imo.<b>im</b> - Android Apps on Google Play',
#              'kind': 'customsearch#result',
#              'link': 'https://play.google.com/store/apps/developer?id=imo.im',
#              'pagemap': {'cse_image': [{'src': 'https://lh6.ggpht.com/653qJf6Ro417FXETOBl3cAJ9hborY6PnCONzLBapvNDw6VgRximFc9YKWDGc82yKKNEV=w170'}],
#                          'cse_thumbnail': [{'height': '136',
#                                             'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRimNtWmf7pxZ6BnSukpQUoroPBHelm5x7R16f_TXWzS_zzuX1wCSWscQJD',
#                                             'width': '136'}],
#                          'metatags': [{'og:title': 'imo.im - Android Apps on '
#                                                    'Google Play',
#                                        'og:type': 'website',
#                                        'og:url': 'https://play.google.com/store/apps/developer?id=imo.im'}]},
#              'snippet': 'With over a million apps and games, Google Play has '
#                         'something for everyone. \n'
#                         'Browse and install your favorite Android apps and '
#                         'games on your Android phone\n'
#                         ',\xa0...',
#              'title': 'imo.im - Android Apps on Google Play'},
#             {'cacheId': 'GF28R9ByR20J',
#              'displayLink': 'chrome.google.com',
#              'formattedUrl': 'https://chrome.google.com/.../ddfbfhabcagnmjekibikpdacoalbmgbl',
#              'htmlFormattedUrl': 'https://chrome.google.com/.../ddfbfhabcagnmjekibikpdacoalbmgbl',
#              'htmlSnippet': 'How do I use Faces? When you receive a facebook '
#                             'message, you&#39;ll get a nice <br>\n'
#                             'little popout chat head on the side of your '
#                             'browser. You&#39;ll start seeing Chat Heads<br>\n'
#                             '&nbsp;...',
#              'htmlTitle': 'faces.<b>im</b>: a facebook messenger for chrome - '
#                           'Chrome Web Store',
#              'kind': 'customsearch#result',
#              'link': 'https://chrome.google.com/webstore/detail/facesim-a-facebook-messen/ddfbfhabcagnmjekibikpdacoalbmgbl',
#              'pagemap': {'aggregaterating': [{'ratingcount': '153',
#                                               'ratingvalue': '3.764705882352941'},
#                                              {'ratingcount': '153',
#                                               'ratingvalue': '3.764705882352941'}],
#                          'cse_image': [{'src': 'https://lh4.googleusercontent.com/EShUtDKpAzvzPMbwZwOd1n8p_7WM8SoqBY-eMCvI_bFOJN4AX9cEGcN_LH9pkOALq7VGLB7TT6Q=s128-h128-e365'}],
#                          'cse_thumbnail': [{'height': '102',
#                                             'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcT7gtwPrdt17GsdiRwYcu6SmezZZj1f-V1QdXS467KbWzin7bng5slw',
#                                             'width': '102'}],
#                          'document': [{'autogen': 'false',
#                                        'available_on_android': 'false',
#                                        'by_google': 'false',
#                                        'canonical': 'true',
#                                        'category': '1_communication',
#                                        'container': 'CHROME',
#                                        'family_unsafe': 'false',
#                                        'item_category': 'EXTENSION',
#                                        'kiosk': 'false',
#                                        'page_lang_safe': 'en',
#                                        'payment_type': 'free',
#                                        'stars2': 'true',
#                                        'stars3': 'true',
#                                        'stars4': 'true',
#                                        'stars5': 'false',
#                                        'supported_regions': 'AE,AR,AT,AU,BE,BG,BR,CA,CH,CL',
#                                        'user_count': '6795',
#                                        'works_offline': 'false'},
#                                       {'autogen': 'false',
#                                        'available_on_android': 'false',
#                                        'by_google': 'false',
#                                        'canonical': 'true',
#                                        'category': '1_communication',
#                                        'container': 'CHROME',
#                                        'family_unsafe': 'false',
#                                        'item_category': 'EXTENSION',
#                                        'kiosk': 'false',
#                                        'page_lang_safe': 'en',
#                                        'pagerank_devurl': '24000',
#                                        'payment_type': 'free',
#                                        'stars2': 'true',
#                                        'stars3': 'true',
#                                        'stars4': 'true',
#                                        'stars5': 'false',
#                                        'supported_regions': 'AE,AR,AT,AU,BE,BG,BR,CA,CH,CL',
#                                        'unpub_user_count': '7767',
#                                        'user_count': '7767',
#                                        'wilson_star_rating': '3.5598280424686513',
#                                        'works_offline': 'false'}],
#                          'metatags': [{'og:description': 'a facebook chat-head '
#                                                          'experience on google '
#                                                          'chrome',
#                                        'og:image': 'https://lh4.googleusercontent.com/EShUtDKpAzvzPMbwZwOd1n8p_7WM8SoqBY-eMCvI_bFOJN4AX9cEGcN_LH9pkOALq7VGLB7TT6Q=s128-h128-e365',
#                                        'og:title': 'faces.im: a facebook '
#                                                    'messenger for chrome',
#                                        'og:type': 'website',
#                                        'og:url': 'https://chrome.google.com/webstore/detail/facesim-a-facebook-messen/ddfbfhabcagnmjekibikpdacoalbmgbl',
#                                        'referrer': 'origin',
#                                        'viewport': 'width=device-width, '
#                                                    'initial-scale=1.0, '
#                                                    'maximum-scale=1.0'}],
#                          'offer': [{'availability': 'http://schema.org/InStock',
#                                     'price': '0',
#                                     'pricecurrency': 'USD'},
#                                    {'availability': 'http://schema.org/InStock',
#                                     'price': '0',
#                                     'pricecurrency': 'USD'}],
#                          'webapplication': [{'applicationcategory': 'http://schema.org/OtherApplication',
#                                              'description': 'a facebook '
#                                                             'chat-head '
#                                                             'experience on '
#                                                             'google chrome',
#                                              'image': 'https://lh4.googleusercontent.com/EShUtDKpAzvzPMbwZwOd1n8p_7WM8SoqBY-eMCvI_bFOJN4AX9cEGcN_LH9pkOALq7VGLB7TT6Q=s128-h128-e365',
#                                              'interactioncount': 'UserDownloads:6,795',
#                                              'name': 'faces.im: a facebook '
#                                                      'messenger for chrome',
#                                              'operatingsystem': 'Chrome',
#                                              'url': 'https://chrome.google.com/webstore/detail/facesim-a-facebook-messen/ddfbfhabcagnmjekibikpdacoalbmgbl',
#                                              'version': '0.2.5.1'},
#                                             {'applicationcategory': 'http://schema.org/OtherApplication',
#                                              'description': 'a facebook '
#                                                             'chat-head '
#                                                             'experience on '
#                                                             'google chrome',
#                                              'image': 'https://lh4.googleusercontent.com/EShUtDKpAzvzPMbwZwOd1n8p_7WM8SoqBY-eMCvI_bFOJN4AX9cEGcN_LH9pkOALq7VGLB7TT6Q=s128-h128-e365',
#                                              'interactioncount': 'UserDownloads:6,789',
#                                              'name': 'faces.im: a facebook '
#                                                      'messenger for chrome',
#                                              'operatingsystem': 'Chrome',
#                                              'version': '0.2.5.1'}]},
#              'snippet': 'How do I use Faces? When you receive a facebook '
#                         "message, you'll get a nice \n"
#                         'little popout chat head on the side of your browser. '
#                         "You'll start seeing Chat Heads\n"
#                         '\xa0...',
#              'title': 'faces.im: a facebook messenger for chrome - Chrome Web '
#                       'Store'},
#             {'cacheId': 'QeITM29X0DEJ',
#              'displayLink': 'chrome.google.com',
# ...
#                          'mobileapplication': [{'contentrating': 'Everyone',
#                                                 'datepublished': 'April 20, '
#                                                                  '2017',
#                                                 'description': 'Have you ever '
#                                                                'wondered what '
#                                                                'is the name of '
#                                                                'a beautiful '
#                                                                'flower you '
#                                                                'have just seen '
#                                                                'in the park? '
#                                                                "What's that "
#                                                                'flower? will '
#                                                                'help you to '
#                                                                'find it out. '
#                                                                'Identify '
#                                                                "flower's "
#                                                                'color, habitat '
#                                                                'and number '
#                                                                'of...',
#                                                 'image': 'https://lh4.ggpht.com/Tp0cghvPPRkEpFcfJEbOpd6PUsJ8nW0_ijSAJGST6GDsR48zRAc5ld8ZElgkVPSGlg=w300',
#                                                 'name': "What's that flower?",
#                                                 'numdownloads': '100,000 - '
#                                                                 '500,000',
#                                                 'operatingsystems': '4.2 and '
#                                                                     'up',
#                                                 'screenshot': 'https://lh6.ggpht.com/uwi-vkSUdGaLFGerTX8yrBi00aSBwliQVkA_V-tsw2EooLpOErM5fV3ORFNM3FtPoLY=h310',
#                                                 'softwareversion': '3.0',
#                                                 'url': 'https://play.google.com/store/apps/details?id=sk.ab.herbs'}],
#                          'offer': [{'price': '0',
#                                     'url': 'https://play.google.com/store/apps/details?id=sk.ab.herbs&rdid=sk.ab.herbs&feature=md&rdot=1'}],
#                          'organization': [{'genre': 'Education',
#                                            'name': 'Adrian Benko',
#                                            'url': '/store/apps/developer?id=Adrian+Benko'},
#                                           {'name': 'Android'}]},
#              'snippet': 'Have you ever wondered what is the name of a '
#                         'beautiful flower you have just \n'
#                         "seen in the park? What's that flower? will help you "
#                         "to find it out. Identify flower's\xa0...",
#              'title': "What's that flower? - Android Apps on Google Play"},
#             {'cacheId': 'PgdkfoB1CFwJ',
#              'displayLink': 'scholar.google.com',
#              'formattedUrl': 'https://scholar.google.com/citations?user=5BsGej8AAAAJ',
#              'htmlFormattedUrl': 'https://scholar.google.com/citations?user=5BsGej8AAAAJ',
#              'htmlSnippet': 'Adaptive evolution of metabolic pathways in '
#                             'Drosophila. JM <b>Flowers</b>, E Sezgin, S <br>\n'
#                             'Kumagai, DD Duvernell, LM Matzkin, PS Schmidt, '
#                             '... Molecular biology and&nbsp;...',
#              'htmlTitle': 'Jonathan M <b>Flowers</b> - Google Scholar '
#                           'Citations',
#              'kind': 'customsearch#result',
#              'link': 'https://scholar.google.com/citations?user=5BsGej8AAAAJ',
#              'pagemap': {'cse_image': [{'src': 'https://scholar.google.com/citations/images/avatar_scholar_150.jpg'}],
#                          'cse_thumbnail': [{'height': '120',
#                                             'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSYat_dh3uuzuaAKHK1jm4UJ9vQLLR2WrNULJy51wzrrHQoG3U1iGEgUQ',
#                                             'width': '120'}],
#                          'hcard': [{'fn': 'Jonathan M Flowers',
#                                     'title': 'Research Scientist, New York '
#                                              'University'}],
#                          'itemlist': [{'itemlistelement': 'Molecular evidence '
#                                                           'for a single '
#                                                           'evolutionary origin '
#                                                           'of domesticated '
#                                                           'riceJ Molina, M '
#                                                           'Sikora, N Garud, JM '
#                                                           'Flowers, S '
#                                                           'Rubinstein, A '
#                                                           'Reynolds, '
#                                                           '...Proceedings of '
#                                                           'the National '
#                                                           'Academy of '
#                                                           'Sciences...'}],
#                          'metatags': [{'format-detection': 'telephone=no',
#                                        'referrer': 'always',
#                                        'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=2'}],
#                          'person': [{'org': 'nyu.edu',
#                                      'role': 'Research Scientist, New York '
#                                              'University'},
#                                     {'jobtitle': 'Research Scientist, New York '
#                                                  'University',
#                                      'name': 'Jonathan M Flowers',
#                                      'worksfor': 'nyu.edu'}]},
#              'snippet': 'Adaptive evolution of metabolic pathways in '
#                         'Drosophila. JM Flowers, E Sezgin, S \n'
#                         'Kumagai, DD Duvernell, LM Matzkin, PS Schmidt, ... '
#                         'Molecular biology and\xa0...',
#              'title': 'Jonathan M Flowers - Google Scholar Citations'},
#             {'cacheId': '00vW8G3ZbS4J',
#              'displayLink': 'scholar.google.com',
#              'formattedUrl': 'scholar.google.com/citations?user=7m3j9NAAAAAJ&hl=en',
#              'htmlFormattedUrl': 'scholar.google.com/citations?user=7m3j9NAAAAAJ&amp;hl=en',
#              'htmlSnippet': 'Vibration thresholds for fretting corrosion in '
#                             'electrical connectors. GT <b>Flowers</b>, F <br>\n'
#                             'Xie, MJ Bozack, RD Malucci. IEEE Transactions on '
#                             'Components and packaging<br>\n'
#                             '&nbsp;...',
#              'htmlTitle': 'George <b>Flowers</b> - Google Scholar Citations',
#              'kind': 'customsearch#result',
#              'link': 'http://scholar.google.com/citations?user=7m3j9NAAAAAJ&hl=en',
#              'pagemap': {'hcard': [{'fn': 'George Flowers',
#                                     'title': 'Auburn University'}],
#                          'itemlist': [{'itemlistelement': 'A study of the '
#                                                           'effect of various '
#                                                           'vehicle properties '
#                                                           'on rollover '
#                                                           'propensityR '
#                                                           'Whitehead, W '
#                                                           'Travis, DM Bevly, G '
#                                                           'FlowersSAE '
#                                                           'Technical Paper, '
#                                                           '2004462004'}],
#                          'metatags': [{'format-detection': 'telephone=no',
#                                        'referrer': 'always',
#                                        'viewport': 'width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=2'}],
#                          'person': [{'org': 'auburn.edu',
#                                      'role': 'Auburn University'},
#                                     {'jobtitle': 'Auburn University',
#                                      'name': 'George Flowers',
#                                      'worksfor': 'auburn.edu'}]},
#              'snippet': 'Vibration thresholds for fretting corrosion in '
#                         'electrical connectors. GT Flowers, F \n'
#                         'Xie, MJ Bozack, RD Malucci. IEEE Transactions on '
#                         'Components and packaging\n'
#                         '\xa0...',
#              'title': 'George Flowers - Google Scholar Citations'},
#             {'cacheId': 'GFYKplTsIoQJ',
#              'displayLink': 'play.google.com',
#              'formattedUrl': 'https://play.google.com/store/apps/developer?id=1-800-flowers...',
#              'htmlFormattedUrl': 'https://play.google.com/store/apps/developer?id=1-800-<b>flowers</b>...',
#              'htmlSnippet': 'With over a million apps and games, Google Play '
#                             'has something for everyone. <br>\n'
#                             'Browse and install your favorite Android apps and '
#                             'games on your Android phone<br>\n'
#                             ',&nbsp;...',
#              'htmlTitle': '1-800-<b>flowers</b>.com - Android Apps on Google '
#                           'Play',
#              'kind': 'customsearch#result',
#              'link': 'https://play.google.com/store/apps/developer?id=1-800-flowers.com',
#              'pagemap': {'cse_image': [{'src': 'https://lh3.googleusercontent.com/Hxw-ppRP-AgD3m_4TY6lc0k825KXMR-qPRa0WSd84ARtDzdBTxVkJftrqqin7JzdKB0=w170'}],
#                          'cse_thumbnail': [{'height': '170',
#                                             'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRzCZg0ScbkCDvUQ9o6xw3ZnWL6jvCDXJ39LHOF8lGtJkLP24NNkCJV7HI',
#                                             'width': '170'}],
#                          'metatags': [{'og:title': '1-800-flowers.com - '
#                                                    'Android Apps on Google '
#                                                    'Play',
#                                        'og:type': 'website',
#                                        'og:url': 'https://play.google.com/store/apps/developer?id=1-800-flowers.com'}]},
#              'snippet': 'With over a million apps and games, Google Play has '
#                         'something for everyone. \n'
#                         'Browse and install your favorite Android apps and '
#                         'games on your Android phone\n'
#                         ',\xa0...',
#              'title': '1-800-flowers.com - Android Apps on Google Play'},
#             {'displayLink': 'sites.google.com',
#              'formattedUrl': 'https://sites.google.com/a/isd181.org/tahnee-flowers/',
#              'htmlFormattedUrl': 'https://sites.google.com/a/isd181.org/tahnee-<b>flowers</b>/',
#              'htmlSnippet': 'Early Childhood Family Education (ECFE)- weekly '
#                             'time together classes for <br>\n'
#                             'parents and their children birth to 5 years old. '
#                             'Our ECFE classes set the stage for<br>\n'
#                             '&nbsp;...',
#              'htmlTitle': 'Tahnee <b>Flowers</b>',
#              'kind': 'customsearch#result',
#              'link': 'https://sites.google.com/a/isd181.org/tahnee-flowers/',
#              'pagemap': {'cse_image': [{'src': 'https://sites.google.com/a/isd181.org/tahnee-flowers/_/rsrc/1372185845793/home/line-fs.jpg'}],
#                          'cse_thumbnail': [{'height': '1',
#                                             'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRjGyoCG-SH5q3LBGwVdunJTYyx0vk1goc8KBr3ZqfVfRdPrLkt5fJj2Iw',
#                                             'width': '600'}],
#                          'metatags': [{'og:image': 'https://sites.google.com/a/isd181.org/tahnee-flowers/_/rsrc/1372185845793/home/line-fs.jpg',
#                                        'og:title': 'Tahnee Flowers',
#                                        'title': 'Tahnee Flowers'}],
#                          'webpage': [{'image': 'https://sites.google.com/a/isd181.org/tahnee-flowers/_/rsrc/1372185845793/home/line-fs.jpg',
#                                       'name': 'Tahnee Flowers'}]},
#              'snippet': 'Early Childhood Family Education (ECFE)- weekly time '
#                         'together classes for \n'
#                         'parents and their children birth to 5 years old. Our '
#                         'ECFE classes set the stage for\n'
#                         '\xa0...',
#              'title': 'Tahnee Flowers'}],
#   'kind': 'customsearch#search',
#   'queries': {'nextPage': [{'count': 10,
#                             'cx': '008351460169727747582:0ryy6yqws-o',
#                             'inputEncoding': 'utf8',
#                             'outputEncoding': 'utf8',
#                             'safe': 'off',
#                             'searchTerms': 'flowers',
#                             'startIndex': 18,
#                             'title': 'Google Custom Search - flowers',
#                             'totalResults': '18600000'}],
#               'previousPage': [{'count': 10,
#                                 'cx': '008351460169727747582:0ryy6yqws-o',
#                                 'inputEncoding': 'utf8',
#                                 'outputEncoding': 'utf8',
#                                 'safe': 'off',
#                                 'searchTerms': 'flowers',
#                                 'startIndex': 1,
#                                 'title': 'Google Custom Search - flowers',
#                                 'totalResults': '18600000'}],
#               'request': [{'count': 10,
#                            'cx': '008351460169727747582:0ryy6yqws-o',
#                            'inputEncoding': 'utf8',
#                            'outputEncoding': 'utf8',
#                            'safe': 'off',
#                            'searchTerms': 'flowers',
#                            'startIndex': 8,
#                            'title': 'Google Custom Search - flowers',
#                            'totalResults': '18600000'}]},
#   'searchInformation': {'formattedSearchTime': '0.80',
#                         'formattedTotalResults': '18,600,000',
#                         'searchTime': 0.803437,
#                         'totalResults': '18600000'},
#   'url': {'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&cref={cref?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json',
#           'type': 'application/json'}}]

# %% [markdown]
# ### Parse the results to find direct links to images
# Add the URLs, Search Terms, and Titles to a list.

# %%
urls = []
terms = []
titles = []
ogImage = ''
cseImage = ''
try: 
    for res in results:
        try: itemsFromRes = res.get('items')
        except: pass

        for item in itemsFromRes:
            try: ogImage = item.get('pagemap').get('metatags')[0].get('og:image')
            except: pass
            try: cseImage = item.get('pagemap').get('cse_image')[0].get('src')
            except: continue

            try:
                #pprint.pprint(item)
                #print(cseImage)
                if ogImage:
                    urls.append(ogImage)
                    print('og:image result: ' + ogImage)

                    titles.append(item.get('pagemap').get('metatags')[0].get('og:title'))
                    print('title: ' + item.get('pagemap').get('metatags')[0].get('og:title'))

                elif cseImage:
                    urls.append(cseImage)
                    print('cse_image result: ' + cseImage)

                    titles.append(item.get('title'))
                    print('title: ' + item.get('title'))

                terms.append(res.get('queries').get('nextPage')[0].get('searchTerms'))
                print('search term: '+ res.get('queries').get('nextPage')[0].get('searchTerms') + '\n')

            except: pass
except: pass

print(len(urls))
#print(urls)    
#print(terms)
#print(len(urls), ' ', len(terms))
# Out:
# cse_image result: https://lh4.ggpht.com/7WFBFNz6ym0PrH_yHG-VMYjudkRAAJuo4G36LdbDhOoXMIKEXZut57PSOL5iLlweKAUN=w300
# title: IM+ - Android Apps on Google Play
# search term: im
#
# cse_image result: https://i.ytimg.com/vi/5DKGe_oEajs/hqdefault.jpg
# title: Skype - free IM & video calls - Android Apps on Google Play
# search term: im
#
# cse_image result: https://lh3.googleusercontent.com/tm_N1osJGfifuRlMfEip4kZFD5QCtd42CYYEhUsxABzIoEn6Nb9UXjRVmjoeKvMFUCzF=w300
# title: imo free video calls and chat - Android Apps on Google Play
# search term: im
#
# og:image result: https://ssl.gstatic.com/chrome/webstore/images/chrome_web_store-128.png
# title: Chrome Web Store
# search term: im
#
# og:image result: https://www.gstatic.com/images/icons/material/apps/fonts/1x/opengraph_color_1200dp.png
# title: Google Fonts
# search term: im
#
# og:image result: https://0.soompi.io/wp-content/uploads/2017/04/21093159/YoonA-Hong-Jong-Hyun-Im-Siwan.jpg
# title: Im Siwan, Hong Jong Hyun, And YoonA Are A Lovely Trio In Upcoming MBC Drama
# search term: im
#
# cse_image result: https://lh6.ggpht.com/653qJf6Ro417FXETOBl3cAJ9hborY6PnCONzLBapvNDw6VgRximFc9YKWDGc82yKKNEV=w170
# title: imo.im - Android Apps on Google Play
# search term: im
#
# og:image result: https://lh4.googleusercontent.com/EShUtDKpAzvzPMbwZwOd1n8p_7WM8SoqBY-eMCvI_bFOJN4AX9cEGcN_LH9pkOALq7VGLB7TT6Q=s128-h128-e365
# title: faces.im: a facebook messenger for chrome
# search term: im
#
# og:image result: https://lh4.googleusercontent.com/HAGJYW-L44P1hVmqxVA77-P181VlVhUf1gyZ-6M7LRKt3MeDsfBhgvSrWSFe4mpan2DY-Kd5h-k=s128-h128-e365
# title: Doit.im
# search term: im
#
# cse_image result: http://www.advocate.com/sites/advocate.com/files/styles/teaser_custom_user_mobile_1x/public/2017/04/22/caitlyne-jennersplainsx750.jpg?timestamp=1492846350
# title: The Advocate
# search term: the
#
# og:image result: http://api.theweek.com/sites/default/files/styles/tw_image_9_4/public/google.jpg?itok=oPJPIpYF
# title: Google is a monopoly — and it's crushing the internet
# search term: the
#
# og:image result: https://cdn0.vox-cdn.com/thumbor/JTDNnKIwd6b-qbjZ7Fv5ldB3hkk=/0x51:1020x625/1600x900/cdn0.vox-cdn.com/uploads/chorus_image/image/54375895/microsoftlogostock2_1020.0.0.jpg
# title: Microsoft's ARM-powered laptops won't arrive until Q4
# search term: the
#
# cse_image result: https://static01.nyt.com/images/2017/04/15/science/15OKLAHOMA4/15OKLAHOMA4-articleLarge.jpg
# title: Affordable Care Act: A Tale of Two Red States - The New York Times
# search term: the
#
# og:image result: https://lh6.googleusercontent.com/vXz0kJD0ISj5Lq6Di4OMG2NqPVCY2xYjjLCg0yyXiBS-Ca1b6grxGPE6aT18M9O2eZLAzZVyFT4=s128-h128-e365
# title: The Great Suspender
# search term: the
#
# cse_image result: https://i.ytimg.com/vi/k8K-VT09X3E/hqdefault.jpg
# title: The Trail - Android Apps on Google Play
# search term: the
#
# og:image result: https://cdn.theatlantic.com/assets/media/img/mt/2017/04/AP_1203270630/facebook.jpg?1492551376
# title: How Poverty Changes the Brain
# search term: the
#
# og:image result: https://lh3.googleusercontent.com/rFFMgS30rrpQJQfRgbRioBqbIIGGLcGD06dj5SXVxh501RHYxRcWJ0uz62Ov-0aOtA=w300
# title: The Founder - Movies & TV on Google Play
# search term: the
#
# og:image result: http://static.politico.com/22/22/ab676d15498e87500012473a4f75/lede-pat-buchanan-24298jpg.jpg
# title: ‘The Ideas Made It, But I Didn’t’
# search term: the
#
# og:image result: http://d3n8a8pro7vhmx.cloudfront.net/thenewcivilrightsmovement/pages/19658/meta_images/original/sheriff_4.jpg?1492733077
# title: 'Please Don’t Touch Me': Police Arrest 10 Year Old Boy With Autism at His School (Video)
# search term: boy
#
# cse_image result: https://lh3.googleusercontent.com/c_bI8tG8TpV-7JD8P3sOEqz2iJ-qRNbGK4amaMWZ0qX_QJIC7HqDtEpeRU7sHa6J-u0=h310
# title: Fallout Pip-Boy - Android Apps on Google Play
# search term: boy
#
# og:image result: http://static.stereogum.com/uploads/2017/04/Phoenix-1488377077-640x434-1492906216.jpg
# title: Phoenix Debut New Songs “Ti Amo,” “J-Boy,” & “Role Model” In Antwerp
# search term: boy
#
# og:image result: http://www.out.com/sites/out.com/files/2017/04/21/boy04_copy.jpg
# title: Premiere: Boy Radio Announces Debut Album 'Neon Romance' & Shares 'Golden Boy' Video
# search term: boy
#
# og:image result: http://www.trbimg.com/img-58fc117b/turbine/os-boy-dead-hit-and-run-20170422
# title: Timber Creek high school student killed in hit-and-run motorcycle collision
# search term: boy
#
# cse_image result: https://i.ytimg.com/vi/fEOI2DMfZb0/hqdefault.jpg
# title: Bulb Boy - Android Apps on Google Play
# search term: boy
#
# og:image result: /wp-content/uploads/2013/03/lifenewsfbthumb.jpg
# title: This Boy Was Almost a Victim of Abortion, Until Something Amazing Happened | LifeNews.com
# search term: boy
#
# cse_image result: https://i.ytimg.com/vi/nUtEzYB-lHs/hqdefault.jpg
# title: Super Meat Boy - Android Apps on Google Play
# search term: boy
#
# cse_image result: https://i.ytimg.com/vi/lvhFBctIgLw/hqdefault.jpg
# title: BMX Boy - Android Apps on Google Play
# search term: boy
#
# og:image result: https://i.kinja-img.com/gawker-media/image/upload/s--4fyDNJIn--/c_fill,fl_progressive,g_center,h_900,q_80,w_1600/gds4nsbiq1pp9eumyald.png
# title: American Airlines Employee Allegedly Hit Woman With Stroller, Challenged Passenger To 'Hit Me' (Updated)
# search term: with
#
# cse_image result: https://lh3.googleusercontent.com/Yr42t3_zVwIo-t1OApktm3gjUOnN7DkSKmUzJENZWdmWGGa4Go9PfI6TMJaaxO60cei0=s530-p
# title: How to use Google Drive - Computer - Google Drive Help
# search term: with
#
# og:image result: https://i.ndtvimg.com/i/2017-04/mumbai-indians_806x605_81492885629.jpg
# title: IPL Highlights, MI vs DD: Mumbai Increase Lead At Top With 14-Run Win Over Delhi – NDTV Sports
# search term: with
#
# cse_image result: http://www.zerohedge.com/sites/default/files/images/user3303/imageroot/2017/04/21/20170421_power2_0.jpg
# title: "Total Chaos" - Cyber Attack Feared As Multiple Cities Hit With ...
# search term: with
#
# og:image result: https://prod01-cdn04.cdn.firstlook.org/wp-uploads/sites/1/2017/04/windows-nsa-malware-users-1492197018-feature-hero.jpg
# title: Leaked NSA Malware Threatens Windows Users Around the World
# search term: the
#
# og:image result: https://si.wsj.net/public/resources/images/BN-SE390_cmogoo_TOP_20170221071116.jpg
# title: Google Plans Ad-Blocking Feature in Popular Chrome Browser
# search term: the
#
# cse_image result: https://lh3.googleusercontent.com/A5Jx9Cvyo-qUGxcdgsDdyLvR9UP_yc2diMLUffxS6snfFka9U-QcjKRflGaw14_j-UOw=w250
# title: Adding the Cast button to the Chrome toolbar - Chromecast Help
# search term: the
#
# og:image result: http://cdn5.thr.com/sites/default/files/2017/04/x-files_s01_premiere_still_1.jpg
# title: 'The X-Files' Revived Again for 10 New Episodes at Fox
# search term: the
#
# og:image result: https://img.washingtonpost.com/rf/image_1484w/2010-2019/WashingtonPost/2016/09/08/Style/Images/596737750-2420.jpg
# title: Ann Coulter rejects Berkeley’s new invite — and a lawsuit may be pending
# search term: the
#
# cse_image result: http://www.advocate.com/sites/advocate.com/files/styles/teaser_custom_user_mobile_1x/public/2017/04/22/caitlyne-jennersplainsx750.jpg?timestamp=1492846350
# title: The Advocate
# search term: the
#
# og:image result: http://api.theweek.com/sites/default/files/styles/tw_image_9_4/public/google.jpg?itok=oPJPIpYF
# title: Google is a monopoly — and it's crushing the internet
# search term: the
#
# og:image result: https://cdn0.vox-cdn.com/thumbor/JTDNnKIwd6b-qbjZ7Fv5ldB3hkk=/0x51:1020x625/1600x900/cdn0.vox-cdn.com/uploads/chorus_image/image/54375895/microsoftlogostock2_1020.0.0.jpg
# title: Microsoft's ARM-powered laptops won't arrive until Q4
# search term: the
#
# cse_image result: https://static01.nyt.com/images/2017/04/15/science/15OKLAHOMA4/15OKLAHOMA4-articleLarge.jpg
# title: Affordable Care Act: A Tale of Two Red States - The New York Times
# search term: the
#
# og:image result: https://lh6.googleusercontent.com/vXz0kJD0ISj5Lq6Di4OMG2NqPVCY2xYjjLCg0yyXiBS-Ca1b6grxGPE6aT18M9O2eZLAzZVyFT4=s128-h128-e365
# title: The Great Suspender
# search term: the
#
# og:image result: https://sites.google.com/site/poetryandtranslations/_/rsrc/1413771021175/home/btn_donate_SM.gif
# title: Vladimir Vysotsky - Russian Poetry in English
# search term: poetry
#
# og:image result: /site/savetheearthpoems/_/rsrc/1440528894510/config/customLogo.gif?revision=5
# title: Save the Earth Poems
# search term: poetry
#
# og:image result: https://books.google.com/books/content?id=fuBHMccJx6UC&printsec=frontcover&img=1&zoom=1&edge=curl&imgtk=AFLRE72HKtTopTnZL_T8ZJzwlld3rpGPb-drhwnA93vM5NvjkkMEEAoGm5Raymzh8hdHYaxla7OH5-MeQWvfiEGjdXGP3XgHeeUVpxv0m8lmnvbny8NEsXhR5A9TiIgMdUMfiTjixm_o
# title: A Poetry Handbook
# search term: poetry
#
# og:image result: https://lh4.ggpht.com/Zi65vUHSU2AmsIrsmX-wU3xNF1JuTpVrtdIpoksCXaKIIg0QI26ArPtPHw
# title: POETRY AND EXILE - Google Arts & Culture
# search term: poetry
#
# og:image result: https://sites.google.com/site/poetryandtranslations/_/rsrc/1413771021175/home/btn_donate_SM.gif
# title: Russian Poetry in English
# search term: poetry
#
# og:image result: https://www.google.com/maps/d/thumbnail?mid=1A1JGJn0T6RmwqtMPFS3OSyhDIWY&hl=en_US
# title: Nanaimo Poetry Map
# search term: poetry
#
# og:image result: https://cdn.theatlantic.com/assets/media/img/2017/04/CULT_Omnivore_Lockwood_Art_Web/facebook.jpg?1491241663
# title: Poet on the Edge
# search term: poetry
#
# og:image result: https://sites.google.com/site/normanfinkelsteinpoetry/_/rsrc/1472783647994/home/img_7191a3sq.jpg?height=320&width=320
# title: Norman Finkelstein: Poetry & Poetics
# search term: poetry
#
# cse_image result: https://lh4.ggpht.com/uPv8JNCLkA3dqq3hylSU-3-EM9bTWDuFGnwSqSd2xU9aZ4dqMxEIwdtCmfP63Qxgzgw=w300
# title: The Poetry App - Android Apps on Google Play
# search term: poetry
#
# og:image result: http://www.powerlineblog.com/ed-assets/2017/04/Crazy-Berkeley.jpeg
# title: The Week in Pictures: I Can't Even Edition
# search term: power
#
# og:image result: http://img-1.newatlas.com/waterlily-charging-turbine-1.jpg?auto=format%2Ccompress&ch=Width%2CDPR&fit=crop&h=347&q=60&rect=253%2C0%2C1667%2C937&w=616&s=2f5e0754a75d0875a114227953621db3
# title: Wet 'n' windy portable turbine spins up battery power off-grid
# search term: power
#
# cse_image result: https://lh3.googleusercontent.com/HrrwQG2huGmKUvmDyfcFdPf-MZSQSM0tgqNlpoqbY1qkMBEPmOMR0PGB9GsrZkGd9gk=w300
# title: Power Security-AntiVirus Clean - Android Apps on Google Play
# search term: power
#
# og:image result: https://cdn2.newsok.biz/cache/r960_blur-d4eaed1a2c41ad17c1ccf5d610b2513d.jpg
# title: High winds snap power poles in northwest Oklahoma City Friday
# search term: power
#
# og:image result: http://i2.wp.com/peopledotcom.files.wordpress.com/2017/04/blake-lively4.jpg?crop=0px%2C0px%2C1579px%2C1184.25px&resize=660%2C495&ssl=1
# title: Watch Blake Lively Hit Back at Reporter Who Asks About Her Outfit at Variety's Power of Women Luncheon
# search term: power
#
# og:image result: https://cdn20.patchcdn.com/users/22926568/20170421/124221/styles/T800x600/public/article_images/power_lines_shutterstock_145163152-1492792933-9570.jpg
# title: San Francisco Power Outage: 'All Customers Are Fully Restored'
# search term: power
#
# og:image result: https://timedotcom.files.wordpress.com/2017/04/an-francisco-power-outage.jpg?w=720
# title: Power Outage in San Francisco Leaves 90,000 People Without Electricity
# search term: power
#
# og:image result: https://i.ndtvimg.com/i/2017-04/san-francisco-power-outage-afp_650x400_41492826662.jpg
# title: San Francisco Power Outage That Stranded People In Elevators
# search term: power
#
# cse_image result: https://i.ytimg.com/vi/igSWSlZRya8/hqdefault.jpg
# title: Power Toggles - Android Apps on Google Play
# search term: power
#
# og:image result: https://lh3.googleusercontent.com/2fZNxhvb0czW0wQ-k2NDsyAl5DdZUs-UHX4F3qXaI--1cIWuK_xcvrqae9-IBquWd2rWJl_26w=s128-h128-e365
# title: Power Thesaurus
# search term: power
#
# cse_image result: https://i.ytimg.com/vi/5DKGe_oEajs/hqdefault.jpg
# title: Skype - free IM & video calls - Android Apps on Google Play
# search term: im
#
# cse_image result: https://lh3.googleusercontent.com/tm_N1osJGfifuRlMfEip4kZFD5QCtd42CYYEhUsxABzIoEn6Nb9UXjRVmjoeKvMFUCzF=w300
# title: imo free video calls and chat - Android Apps on Google Play
# search term: im
#
# og:image result: https://ssl.gstatic.com/chrome/webstore/images/chrome_web_store-128.png
# title: Chrome Web Store
# search term: im
#
# og:image result: https://www.gstatic.com/images/icons/material/apps/fonts/1x/opengraph_color_1200dp.png
# title: Google Fonts
# search term: im
#
# og:image result: https://0.soompi.io/wp-content/uploads/2017/04/21093159/YoonA-Hong-Jong-Hyun-Im-Siwan.jpg
# title: Im Siwan, Hong Jong Hyun, And YoonA Are A Lovely Trio In Upcoming MBC Drama
# search term: im
#
# cse_image result: https://lh6.ggpht.com/653qJf6Ro417FXETOBl3cAJ9hborY6PnCONzLBapvNDw6VgRximFc9YKWDGc82yKKNEV=w170
# title: imo.im - Android Apps on Google Play
# search term: im
#
# og:image result: https://lh4.googleusercontent.com/EShUtDKpAzvzPMbwZwOd1n8p_7WM8SoqBY-eMCvI_bFOJN4AX9cEGcN_LH9pkOALq7VGLB7TT6Q=s128-h128-e365
# title: faces.im: a facebook messenger for chrome
# search term: im
#
# og:image result: https://lh4.googleusercontent.com/HAGJYW-L44P1hVmqxVA77-P181VlVhUf1gyZ-6M7LRKt3MeDsfBhgvSrWSFe4mpan2DY-Kd5h-k=s128-h128-e365
# title: Doit.im
# search term: im
#
# og:image result: https://lh6.googleusercontent.com/vXz0kJD0ISj5Lq6Di4OMG2NqPVCY2xYjjLCg0yyXiBS-Ca1b6grxGPE6aT18M9O2eZLAzZVyFT4=s128-h128-e365
# title: The Great Suspender
# search term: the
#
# cse_image result: https://i.ytimg.com/vi/k8K-VT09X3E/hqdefault.jpg
# title: The Trail - Android Apps on Google Play
# search term: the
#
# og:image result: https://cdn.theatlantic.com/assets/media/img/mt/2017/04/AP_1203270630/facebook.jpg?1492551376
# title: How Poverty Changes the Brain
# search term: the
#
# og:image result: https://lh3.googleusercontent.com/rFFMgS30rrpQJQfRgbRioBqbIIGGLcGD06dj5SXVxh501RHYxRcWJ0uz62Ov-0aOtA=w300
# title: The Founder - Movies & TV on Google Play
# search term: the
#
# og:image result: http://static.politico.com/22/22/ab676d15498e87500012473a4f75/lede-pat-buchanan-24298jpg.jpg
# title: ‘The Ideas Made It, But I Didn’t’
# search term: the
#
# cse_image result: https://lh3.googleusercontent.com/jsVZGkk_wvGK80olCcnJRm2UrITErmLd2r8lCzBJZ9ZDk3UOujELkqj-9FAazE7UqrOe=w240
# title: How to Factory Data Reset (FDR) your Chromecast - Chromecast Help
# search term: the
#
# og:image result: https://www.city-journal.org/sites/cj/files/27_2-cc1.jpg
# title: The French, Coming Apart
# search term: the
#
# cse_image result: https://lh3.googleusercontent.com/zDmbv8p89ftAYuY9ddwkJq6JkrAXxaaM6Fnfy5RewJnen01Szlpu4Z-JPka8ri8Lsg=h310
# title: The Escapists - Android Apps on Google Play
# search term: the
#
# og:image result: https://o.aolcdn.com/images/dims?thumbnail=1200%2C630&quality=80&image_uri=https%3A%2F%2Fs.aolcdn.com%2Fhss%2Fstorage%2Fmidas%2Fd906fbd0441af4a7e5d5893eaaec1a04%2F205189977%2Fnews.gif&client=cbc79c14efcebee57402&signature=d8a7f3a77d42a27096346a1b2f2e70cfc8fffd5f
# title: The Morning After: Weekend Edition
# search term: the
#
# og:image result: http://www.trbimg.com/img-58fc117b/turbine/os-boy-dead-hit-and-run-20170422
# title: Timber Creek high school student killed in hit-and-run motorcycle collision
# search term: boy
#
# cse_image result: https://i.ytimg.com/vi/fEOI2DMfZb0/hqdefault.jpg
# title: Bulb Boy - Android Apps on Google Play
# search term: boy
#
# og:image result: /wp-content/uploads/2013/03/lifenewsfbthumb.jpg
# title: This Boy Was Almost a Victim of Abortion, Until Something Amazing Happened | LifeNews.com
# search term: boy
#
# cse_image result: https://i.ytimg.com/vi/nUtEzYB-lHs/hqdefault.jpg
# title: Super Meat Boy - Android Apps on Google Play
# search term: boy
#
# cse_image result: https://i.ytimg.com/vi/lvhFBctIgLw/hqdefault.jpg
# title: BMX Boy - Android Apps on Google Play
# search term: boy
#
# og:image result: https://timedotcom.files.wordpress.com/2017/04/gettyimages-567374107.jpg?w=720
# title: Ellen and Bradley Cooper Refuse to Let Nugget Boy Come for Their Retweet Record
# search term: boy
#
# cse_image result: https://i.ytimg.com/vi/jEWWcQNCzVk/hqdefault.jpg
# title: Bullet Boy - Android Apps on Google Play
# search term: boy
#
# cse_image result: https://i.ytimg.com/vi/Urrw7p1J0cs/hqdefault.jpg
# title: Skater Boy - Android Apps on Google Play
# search term: boy
#
# og:image result: https://assets.bwbx.io/s3/javelin/public/javelin/images/social-default-a4f15fa7ee.jpg
# title: Analyst Who Predicted Trump’s Ascendancy Bets on Le Pen Win
# search term: who
#
# og:image result: https://www.usnews.com/cmsmedia/c1/eb/79b39630470a91a81809237a40cb/170420-editorial.jpg
# title: Charges for Pot Activists Who Offered 4/20 Joints to Congressional Staff
# search term: who
#
# og:image result: http://i2.cdn.cnn.com/cnnnext/dam/assets/170420083224-donald-trump-and-the-new-england-patriots-april-19-2017-super-tease.jpg
# title: Trump recognizes player who isn't there - CNN Video
# search term: who
#
# cse_image result: https://i.ytimg.com/vi/jGO4-lHCDM0/hqdefault.jpg
# title: Who Lurks - Android Apps on Google Play
# search term: who
#
# og:image result: http://cdn.images.express.co.uk/img/dynamic/78/750x445/735118.jpg
# title: French election 2017 polls: Will Fillon, Le Pen or Macron win? Latest polls and odds
# search term: who
#
# og:image result: http://www.newyorker.com/wp-content/uploads/2017/04/Borowitz-JaredKushnerCallsKimJong-unTotallyUnqualified-Social.jpg
# title: Jared Kushner Calls Kim Jong-un “Totally Unqualified Person” Who Only Got Job Through Nepotism
# search term: who
#
# og:image result: https://si.wsj.net/public/resources/images/BN-TB251_alztes_TOP_20170420121131.jpg
# title: Novartis Tests New Alzheimer’s Drug on People Who Don’t Have the Disease
# search term: who
#
# og:image result: http://ll-media.tmz.com/2017/04/21/0421-loraine-gilles-mel-b-tmz-composite-2-1200x630.jpg
# title: Mel B Sued for Defamation By Nanny Lorraine Gilles Who Claims They Had 3-Way Sex
# search term: who
#
# og:image result: http://snagfilms-a.akamaihd.net/36/51/f53bc33e4f59981b753e1cc3fdae/gavel.jpg
# title: Man who went AWOL 45 years ago home after 30-day sentence
# search term: who
#
# og:image result: http://i.dailymail.co.uk/i/pix/2016/10/28/22/0B1A526A000005DC-0-image-a-34_1477688752794.jpg
# title: Video reveals the chemicals that make up the 'scent of death'
# search term: smells
#
# og:image result: https://lh6.ggpht.com/rv1JA9Tojw65Tx75-ly8p20NKcn2aFXuxOitWPv4h5_f-QFaFV_QV2tjhaILamzBJT5GvjHij2w
# title: Smells Like Teen Spirit - Nirvana
# search term: smells
#
# og:image result: https://books.google.com/books/content?id=0SH3tSXCzx4C&printsec=frontcover&img=1&zoom=1&edge=curl&imgtk=AFLRE71Qgo5jeC0rqZqCQliG2FoQ6xWlO0BZgmzdCaGeYlprhIwlO2uvUtMpVxva205OKI7PpqVhl9txhvZWQsjANvGphEmTtbE5uBNVT1o7MjWQc0jXXbfYDasofi_Mh4tmregmg2kK
# title: The Wonderful Smells
# search term: smells
#
# og:image result: http://www.aromasteam.net/images/stories/health_benefits/olfactory_system.jpg
# title: Smell and Taste - Super Sensation Nation
# search term: smells
#
# og:image result: http://www.google.com/images/icons/product/groups-128.png
# title: What Smell do Cats HATE?
# search term: smells
#
# og:image result: /a/aguafria.org/susan-wanzer/_/rsrc/1375726659299/config/customLogo.gif?revision=1
# title: Chemistry of Smells Notes/Activities - Susan Wanzer
# search term: smells
#
# cse_image result: https://lh3.googleusercontent.com/-IwmoYJoejrw/VwXGZdZCKKI/AAAAAAAAE-4/Rpzl6ltMiOARb3yB8RA4c0rQH34DrL9DA/s320/IMG_20160406_214838.jpg
# title: Controller Box Smells Like Burning Di3 - Google Groups
# search term: smells
#
# cse_image result: http://answers.google.com/answers/answers-logo-sm.gif
# title: Google Answers: How to make the "old apartment smell" go away
# search term: smells
#
# og:image result: http://www.trbimg.com/img-58fa0dda/turbine/la-me-ln-metro-rider-committee-20170420
# title: Next stop for L.A. Metro: A committee focusing on what it's like to be a rider
# search term: like
#
# og:image result: //a57.foxnews.com/images.foxnews.com/content/fox-news/entertainment/2017/04/20/sylvester-stallones-daughters-reveal-what-it-was-like-growing-up-with-their-famous-dad/_jcr_content/par/featured-media/media-0.img.jpg/0/0/1492626205472.jpg?ve=1
# title: Sylvester Stallone's daughters reveal what it was like growing up with their famous dad
# search term: like
#
# og:image result: https://lh3.googleusercontent.com/R0ihO3g4TDOUVTyvn70QvWtcsG9JfqOlDUmqD0_IbawmIWW2W2-kjndedFXR9R_nbB4YzNa_=s128-h128-e365
# title: Like
# search term: like
#
# og:image result: https://thoughtcatalog.files.wordpress.com/2017/04/30768483570_92ba212422_k-1.jpg
# title: You Think He’s Playing Games But He Just Doesn’t Like You
# search term: like
#
# cse_image result: https://lh3.googleusercontent.com/z_dVaAGWaYGLulTy0drwYY6QpdABEOq718yBnFyw6Ejbu9T_r4-3FyOVCb0aNw=s400-p
# title: Control what others see about you across Google services - Google ...
# search term: like
#
# og:image result: http://pixel.nymag.com/imgs/daily/vulture/2017/04/22/22-chris-pratt.w1200.h630.jpg
# title: Chris Pratt: Saying No One Makes Movies About People Like Me Was ‘Pretty Stupid’
# search term: like
#
# og:image result: https://cnet1.cbsistatic.com/img/rMloW_jPcup_nxK0j3CSJiRt36M=/670x503/2017/04/21/fd9d5ac2-5330-41e8-bbed-53ca429b7e9a/cassiniearth.jpg
# title: This is what Earth looks like from Saturn
# search term: like
#
# og:image result: https://tctechcrunch2011.files.wordpress.com/2017/04/gather-spam-ios.jpg?w=764&h=400&crop=1
# title: Don’t get played by this spammy app like I did
# search term: like
#
# og:image result: https://lh6.googleusercontent.com/eYOlxwfgWjcw2UIv5gS6jSz7DgNCdjR4sZo8zdGPHrAeE2x5Qy58i6-1hfjXwSgjuqM58afEKA=s128-h128-e365
# title: Like all, plus all, favorite all
# search term: like
#
# og:image result: http://i.amz.mshcdn.com/1iJHuyMZ2nNOxs4oP0BC1kwS044=/1200x630/2017%2F04%2F21%2Fcc%2Fa0092512f7284ddab39cb77990b23bf6.d254f.png
# title: William and Harry tell Kate what it was really like after they lost their mum
# search term: like
#
# og:image result: https://lh3.googleusercontent.com/m_gP_6fdMCncD4eleTFPwjP-HyUf9Aw3zivnyJPZ3wktQkvKk1beqaYkMfxO3uQl8LtJmfLf=s128-h128-e365
# title: My Flowers New Tab - HD Wallpapers
# search term: flowers
#
# og:image result: https://lh5.googleusercontent.com/ee2_Xo1ito6RFbHxwgIjHB0GKuTZRxOVMwG6COiyn8qwKB4Pz_a7yQaJsf3Fxr_4ooijL3PgSw=s128-h128-e365
# title: Field of flowers
# search term: flowers
#
# og:image result: https://www.gstatic.com/gsx/Google_Express_Product_Icon_FC_RGB.png
# title: Google Express - 1-800-FLOWERS Peninsula
# search term: flowers
#
# cse_image result: https://lh3.googleusercontent.com/gIYR7Z8RazwKtC2q9OW7e8UXMPd2QN0CImZOFJkYbqFfLqjQgjhVx5P2DPi4TmNsRQ=w300
# title: 1-800-Flowers.com: Send Gifts - Android Apps on Google Play
# search term: flowers
#
# cse_image result: https://lh4.ggpht.com/Tp0cghvPPRkEpFcfJEbOpd6PUsJ8nW0_ijSAJGST6GDsR48zRAc5ld8ZElgkVPSGlg=w300
# title: What's that flower? - Android Apps on Google Play
# search term: flowers
#
# cse_image result: https://scholar.google.com/citations/images/avatar_scholar_150.jpg
# title: Jonathan M Flowers - Google Scholar Citations
# search term: flowers
#
# cse_image result: https://lh3.googleusercontent.com/Hxw-ppRP-AgD3m_4TY6lc0k825KXMR-qPRa0WSd84ARtDzdBTxVkJftrqqin7JzdKB0=w170
# title: 1-800-flowers.com - Android Apps on Google Play
# search term: flowers
#
# og:image result: https://sites.google.com/a/isd181.org/tahnee-flowers/_/rsrc/1372185845793/home/line-fs.jpg
# title: Tahnee Flowers
# search term: flowers
#
# 120

# %% [markdown]
# ### Download and label each image.
#
# Folder will be created in the working directory (where you're running this code from). Folder name = proj. Subfolders include the original images and the labeled/resized ones. In addition, a file called urls.txt will be written that includes the url, search term, and title for each source.

# %%
# create working directory
proj = 'flowers1'
cwd = os.getcwd()
os.mkdir(proj)
os.chdir(proj)
cwd = os.getcwd()
os.mkdir('originals')
os.mkdir('labeled')

# write urls to txt file
urlsFile = open('urls.txt', 'w')
i = 0
for url in urls:
    urlsFile.write('%s\n%s\n%s\n\n' % (url, terms[i], titles[i]))
    i += 1

urlsFile.close()
os.chdir('..\\')

# set font for labels
font = ImageFont.truetype("couri.ttf", 64)

i = 0
for term in terms:
    try:
        url = urls[i]
        i += 1
        imageTuple = urllib.request.urlretrieve(url, '.\\' + proj + '\\originals\\' + str(i) + '_' + term + '.jpg')
        
        # open and resize to 640x640
        image = Image.open(imageTuple[0]).resize((640, 640), Image.BILINEAR)
        
        # overlay search term
        draw = ImageDraw.Draw(image)
        draw.rectangle(((0, 100), (40*len(term), 170)), fill='black', outline=None)
        draw.text((0, 100),term,(255,255,255),font=font)
        
        image.save('.\\' + proj + '\\labeled\\' + str(i) + '_' + term + '_labeled.jpg')
    except:
        pass
